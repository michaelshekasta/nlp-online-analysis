# %%
##Creating a list of stop words and adding custom stopwords
import codecs
with codecs.open('bgulex.utf8.hr', 'r', encoding='utf8') as f:
    text = f.read()

# %%
file_type = 'thread'
field_name = 'title'

# %%
lines = text.split('\n')

# %%
words_in_heb_dict = set()
for line in lines:
    word = line.split(':')[0].split(' ')[0].strip().replace(' DEF','')
    if len(word) > 0:
        words_in_heb_dict.add(word)

# %%
##Creating a list of stop words and adding custom stopwords
import codecs
with codecs.open('army_dictionary.txt', 'r', encoding='utf8') as f:
    text = f.read()

# %%
lines = text.split('\n')

# %%
words_in_army_dict = set()
for line in lines:
    words_in_army_dict.add(line.replace('\"',""))

# %%
import pickle
import re

# %%
pickle_file = open(f'{file_type}_{field_name}_token_lists.pickle', "rb" )
corpus = pickle.load( pickle_file )
pickle_file.close()

# %%
problem_words = list()
good_words = list()
joined_words = list()
prev_raw_word = ''
for sentence in corpus:
    for raw_word in sentence:
        word = re.sub(r'[!|?|\.|,|-|\(|\)|:|\*|;|\-|\+\/|\'|״]','',raw_word)
        if not word in words_in_heb_dict and not word.isdigit():
            joined_word = str(prev_raw_word+word)
            if len(word) > 1:
                if joined_word in words_in_heb_dict:
                    joined_words.append(joined_word)
                else:
                    if len(prev_raw_word) == 1:
                        problem_words.append(joined_word)
                    else:
                        problem_words.append(word)
        else:
            good_words.append(word)
        prev_raw_word = word

# %%
print('ratio problematic words')
print(float(len(problem_words))/((len(good_words))+len(joined_words)+len(problem_words)))
# Out:
# ratio problematic words
# 0.05789252287306762

# %%
print('unique ratio problematic words')
print(float(len(set(problem_words)))/((len(set(good_words)))+len(set(joined_words))+len(set(problem_words))))
# Out:
# unique ratio problematic words
# 0.26620010368066355

# %%
count_army_words = 0
for i in set(problem_words):
    if not i in words_in_army_dict:
        print(i)
# Out:
# שביקשתי
# לדתיים
# צילנדר
# מAMAN
# טיפשית…
# הגובניק
# שיחרורם
# המכיניסטים
# להעבור
# בונזו
# הטירונותלא
# בסינימה
# הזעורה
# הטיחות
# הממ
# שריונר
# רמ
# הלונאי
# מסייעתפלסר
# דחוףףףףףףףףףףףףףףףףףףףףףף
# בראור
# תיהיה
# מדצמבר19
# הבייתה
# בגולני
# נדחוידחו
# אובדניות
# הelite
# יוב
# מצחהאם
# רמח
# מ05בגדוד
# פזםהולדת
# בגיבושיםפרטי
# 210מחנה
# צלילהזה
# נראלכם
# עך
# תשובותמודיעין
# לקצןנה
# הינא
# מנתקים
# לימדי
# הטנקיסטיות
# וחצי~3
# מילואימניקים
# בפורום
# תשירות
# הקדצ
# הייאתמול
# דחןף
# אניגמה
# דחוףף
# הרמ2
# טובהיתרונות
# שעברואמורים
# ןהכל
# ליתרום
# 1tu16095
# שיאון
# דכאון
# מיוחדתימי
# גניקומסטיה
# #התחלנו
# לינואר
# פלטינות
# טוקסידו
# הרבקו
# אוירית
# השוקייםכנראה
# פרופילתפקיד
# פיקודהדרכה
# לבסמח
# אפליקציית
# מכטב
# הודחה‎
# לבנותזה
# כלכך
# בקורונה
# למפקצ
# 2למבינים
# האווירמה
# hood
# הריאון
# m16
# ביחידות
# הראבק
# המזי
# פלחץלוחמי
# פראמדיק
# בקרביבסיס
# בווצאפ
# מאקם
# שאן
# פקער
# קצרשים
# אלחוטנית
# זתסך
# לתש
# תכלס
# פיזטורפיה
# בקשותערעור
# הנפיים
# רתששירת
# תמנילה
# סילס
# זיס
# אוווירי
# DNA
# מישהוי
# בשריון
# primer
# שתרצואיפה
# נתממניקים
# שטאלים
# בשלדג669
# האוטופד
# FAQ
# נעט
# M4
# האחמ
# השחקיםתלפיותכלל
# לאוטיסט
# מישהיו
# למתגייסי
# מתפש
# עזרההה
# מולאנים
# גדעונים
# ccna
# מאחורה
# בynet
# סייכוי
# דםהקזת
# אישימה
# בראשון
# חריףף
# ג׳ובים
# למוידעין
# when
# הצבאזה
# 2ממשקית
# 2גימליםעל
# מצגייס
# 5פוסל
# קומבינה
# מטורפיםפשוט
# הילפני
# חטיבתיים
# מלחתחילה
# ערביתמחשבים
# החופל
# about
# הסדרניק
# העלת
# לרצועה
# השנייהעוצר
# idf
# היקורופא
# בעתיד
# תוכניתןיתתקשוב
# צימידאן
# רחפנים
# Xbox
# הוז
# בתפקידלשעבר
# איזבץה
# לקריה
# מפלגמפקדת
# המחשבתכנות
# הצורניותמה
# סיסטםתשתיות
# נפקדותעריקות
# הליכהמסע
# מגעהדרכה
# חח
# הבהד
# רשלצ
# לגדנע
# ליומס
# למלשבים
# צה”ל
# בצבא
# תיד
# פסיכוטכנית
# א’
# לשחמ
# קילופיםעור
# הערכהצפימישהו
# גבעתיכפיר
# סראבק
# הקיריה
# מתיייייייייייייייייי
# תאגדים
# אווירש13
# השעבר
# הקקצ
# הקורונולה
# התלפיות
# טרמיות
# צהלמה
# שיתנו
# וג׳וב
# מטוויח
# כומהתה
# בעייות
# קציעות
# ד׳
# גולנציקים
# חוףהכרמל
# אקדימת
# תומכ
# כנפצ
# 45דפר
# לצהל
# שוורצנגר
# paladium
# להגנמ
# 1לאוגוסט
# פרופילקבאדפר
# מגלר
# טרמי
# האוק
# miloim
# מיכלי
# לקורונה
# מהקבא
# פיזותרפיה
# עיניין
# דחייההקדמה
# 100אחוז
# המימז
# ראבקיסטים
# ERP
# בטכלס
# 3peak
# מקחר
# בנגיי
# פסכייטר
# לעזרה
# דוסים
# ברזלאנשים
# טינטון
# מכיניסט
# מיוןרוצה
# המחוה
# בספטמבר
# GL
# fuckkkkkkkkkkkkkk
# הzoom
# הוטר
# הפסיכיטר
# סלאטים
# אינטלגניותסלאביות
# הומופוביה
# בירפא
# מודעין
# היפותטית
# סמג
# הלונאים
# פרמדיקיש
# והרג
# קהס
# הירנית
# ממזי
# 4גימלים
# עזרה🙏🏻
# —התש—
# לנוב
# הגיהאד
# אוקטוברנובמבר
# המדס
# המתסבך
# dji
# מעודפת
# קציון
# הסייראת
# האפ
# שוחררררר
# סייראת
# לשבס
# קפצניק
# מיחטיות
# אבהותבדיקת
# כחובשת
# פב
# המוהנדסים
# Data
# אוטואימוניות
# גרביטי
# מדפר
# לנסא
# Aim
# tbdkv
# הרואקוטן
# היהק
# בבחא
# וניראלי
# רחוקח
# ערעורחריג
# רמ2
# העדפותעולמות
# ואחרי
# פוטותרפיה
# שלרדת
# 4קהס
# אייזנקוט
# סבוריה
# [שין
# ואבכ
# הצבאהנדסת
# עמצאי
# 57%
# גיוסיעזור
# ה64מלשב
# יאדפר
# מקפס
# מדירכת
# לגעת
# ספוט
# פלחץחיר
# דיגיטל
# וקיצני
# OOF
# 43תפקידים
# רפואיאישי
# סימנוב
# השבועשבוע
# דחש
# נתממניק
# טיקטוק
# שחקיםחבצלות
# דאעש
# עוהד
# השחמ
# הש13
# להגיסטים
# חובשיים
# שאבור
# לפטופ
# 4קורונה
# ניידבלוני
# המסלולטירונות
# MLRS
# למיכינסטים
# בביפים
# ושייקיםוברד
# ID
# בישביל
# הרצינים
# וM16
# 🙏🏼
# עזרההייתי
# סיליקון
# אניגמהמפנה
# לקנותלהביא
# הסייבר8200
# למתגייסים
# דליס
# בצוו
# טימטום
# שקבנים
# בשחרור
# התףהאורתופד
# האזרחןת
# הוס
# ששירתו
# מקדולנס
# ודיגום
# אופטיקה
# טרגט
# טריפ
# רשעון
# ההתדנבות
# מיןניפ
# ynet
# תגזרות
# הלומדהלבנות
# pt
# סופטשל
# דובדבןמגלןגולניגבעתי
# גנשים
# השקמיסטים
# הואני
# למגל
# בפייסבוק
# אקו
# הוחמות
# אוג׳
# המנילהשאלון
# FXP
# מגולני
# מסאל
# מביקוררןפא
# הקבנים
# talked
# 3חודשיםמישהו
# ACL
# נצאאא
# ימיעצה
# הhell
# אגוז🌰
# אוטוטו
# אלקטרואופטיקה
# ופקל
# in
# הצבאדחוף
# להתגייסמפחד
# בדחש
# 2020אתם
# ווסאח
# Apple
# משרתיםשירתתם
# מיניסקוס
# מקורס
# וADHD
# מטכל669
# אליואני
# כטבחמעדיף
# במחווהאל
# פתןר
# קומדנו
# ולקבש
# רקוטן
# ההשתחררמוקדש
# הרטה
# צוללותשבוע
# כאלו
# 3דחוףף
# דיגטל
# יותרחוקר
# נובלמטרת
# מ110
# kill
# הטיררונות
# טייסתבסיס
# בבקוםלשכת
# היומסניקים
# סיבברררררררררררר
# הנגביסטים
# אעמ
# הדיסקיות
# להיתאבד
# שאלהאם
# קצרש
# טרולים
# קירל
# קורסיסטים
# שואלנהג
# פסוריאזיס
# רישמי
# הדורגלים
# הקורסמסלול
# מרצ
# ההולטר
# המשפחנ
# הקלנדיה
# לטת
# המדאגנעת
# הולץ
# קצונהמכיםוכו
# אוק
# מאלשח
# מעתודה
# ואללה
# אורטופד
# מפק׳
# מגרנותכאבי
# תעזרווו
# הצנחניםקרבי
# סיייבברררר
# בביסלח
# הנסו🙏🏻
# דפר60
# אוייבים
# באוק
# החבר׳ה
# הרספ
# ביולוגיה
# השיחרור
# יחדות
# חשובב
# שפלחץ
# הייזר
# דחוףףףףף
# החמסבר
# ⬅️
# בטלפון
# מצהל
# תגת
# במסנג׳ר
# בטירונות
# רפאויות
# בבית
# מחראני
# סדנא
# לשושים
# חקמ
# התש5
# גוד
# הפסיכוטכניים
# פמטכל
# מושץ
# הייקיבלתי
# SMSים
# בתש
# למפ
# חיליחידה
# הקנותלהכין
# חסרנותירונות
# שיפצורים
# בלונאי
# בקדצ
# הפרויקטנטים
# קורדינציה
# לפקלש
# עתק
# טנקיסטים
# הריאיונות
# כ400
# מודעיין
# מדמח
# VS
# ריפוטצייה
# דיפוזי
# הרמ
# שרוצהחירכמה
# lowa
# פרופגנדה
# ~כנסו~
# ימלשב
# תכנותקיבלתם
# חיילקצין
# החמישימתחיל
# חארטה
# היםחיל
# שוויתרה
# תאבחון
# הפרוםיל
# רפואייםזה
# סולימני
# הידיוק
# במוצב
# היממ
# אוטיסטים
# ופלחץ
# הקתפיים
# במילואים
# הית
# לאנשי
# אןתי
# כוסאמא
# לחימושניקים
# זמ
# 8יום
# התנדבותיות
# ממתם
# בנותרוצה
# טממ
# שמשקיעים
# קבא51דפר60הוא
# הקומנדו669
# יממ
# לחמשושים
# and
# מרמור
# רם2
# שחקניםתובנה
# האישיותי
# גבסופש
# עלמש
# סטילים
# שחקיםעזרה
# yakpizo
# טובמקצועי
# באסהההההההההההההה
# הלוקרים
# מבסמח
# הmri
# ב1215
# אקניל
# הMRI
# ריאיונות
# תהנו
# חיילחימוש
# פקדון
# חטיבהגדוד
# טכנולוגילוגיטקהנדסאי
# לוחםלעצמכם
# המיניסקוס
# האנימה
# עזרהמיטב
# בעיניי
# הקרקל
# לאפריל
# פיזיותרפיה
# קהס42
# שייטת13
# חוזריאני
# אייפון
# מיחידו
# הצמפ
# הנפצות
# מייםדוהר
# 53%
# הקיטבאג
# הצליאקים
# first
# הציפרלקס
# מיוניםאניגמה
# הןא
# אוג17
# יאאלה
# החיזמא
# הnavy
# הגיוני😂
# פלייסטשיין
# פוט
# מתפקידים
# הרמד
# נובדצמבר
# לשחרור
# השבכ
# ופלחצ
# הרהן
# גרומט
# פציעהאני
# הלוטר
# חהא
# הM16
# אוירפרטים
# טוביםרעים
# jpg
# הוחרים
# 50נשבע
# להפנייה
# ברכיות
# אסמטית
# הלבניםשקופים
# Xiaomi
# הקירייה
# הוותר
# תפיקדון
# היינתים
# הדינות
# מחררר
# החפשש
# טכנולוג
# החרפ
# לתפקידלקבל
# ממצ
# בפיקודית
# חטפ
# בסדיר
# ביג
# בצריפין
# חיילית
# לגוליס
# גובתומכל
# ווטצאפ
# צנחניםכמה
# למקצועות
# התוחתנים
# מיוןחיל
# קבןמלשב
# הברהן
# השקמ
# חטמר
# כניראה
# וישתחררתי
# אפאצי
# מצים
# pcap
# האוירעוקץ
# חרסינהגאליס
# היווי
# לייזר
# החברוןמשמר
# פיזחקה
# לחמל
# משקש
# שתכלס
# Bee
# week
# בבהד
# תפקידכנסו
# בשבוע
# אלטרוניקה
# ואסמכתא
# המסול
# בצרועה
# המפלז
# 3ocd
# מתשאלצלפים
# חייילאוויר
# ידהנדסאיעתודה
# הפקל
# לשיחרור
# לפסכיאטר
# הZOOM
# דאבל
# מנדפות
# כנסוו
# נבאללה
# לשריון
# שםמה
# המישוא
# קורסתפקיד
# אדין
# המקסימלית
# גימני
# לחודש
# חזותימפענחי
# מקצועע
# תנפש
# נובדצמ
# מס׳
# מ64
# דדליפט
# הוחמת
# הילו
# הדפרהקבא
# ספאמר
# הולם1
# 319אני
# ורציתע
# להציר
# מחר101119
# DC
# מטריל
# ודחש
# יטם
# נובי
# קרביתתותחנים
# הטוויסט
# לנתממ
# גדנע
# הסופשים
# הביקורופא
# הובשים
# #רקרבי
# fifa
# מטש
# פסיכאטרי
# קנאביס
# מפחט
# סנייפר
# היצאות
# במנילה🤨
# התחבצ
# כןכן
# פאץ׳
# חט׳
# הסופש
# הוייםחטופים
# שחור90
# daniel1997daniel
# להיתקבל
# אלגוריתמיקי
# רשיוןיש
# מחיפה
# טכ
# מיתבחים
# הבהדים
# הבסמח
# אדמ
# אוקנוב
# נמאסס
# דובדבן🙏🏼
# הרסרית
# מקסימאלים
# נהב
# חשמלפיזיקה
# וי
# וחודשנתנו
# הקרדית
# חנתר
# שעכשיוהיה
# ברזלהאם
# פדחני
# הזאתי
# מודיעינים
# תעופתית
# העצוד
# החמן
# בבאח
# פילילי
# מדמחתכניתנים
# מפגריםהזויים
# אסמכתא
# פרופיל21
# הנסאי
# ללק
# מפלז
# מנטלי
# העצתרפו
# הקקץ
# מאיסוף
# ייעדויות
# בתזונה
# גנרטורים
# רפ
# ג׳אליס
# מאוג
# חגאי
# המבא
# השבוזים
# הידוד
# הטכונולוגיים
# מביןגיבוש
# ערעורקבילה
# יצוגית
# בללכת
# פלוגתית
# הקצרש
# העירעור
# הארנביא
# הודד
# לתלפיות
# מקרפר
# פסיכוטכניים
# השביזות
# ביקורופא
# ארטרוסקופיה
# m16שואל
# במצטבר
# היג
# שירתתי
# Wtf
# צקיכה
# משקיות
# עזרהצריך
# במטווח
# הטאלנט
# הלשהו
# במרכז
# מדאגית
# אלמוז
# שחחר
# תוכניתנים
# המצ
# גדסרים
# מועודף
# דצמבראפריל
# תשאלון
# המדין
# הייט
# ברצףכמה
# לכולם
# תש3
# טירונותתתתת
# הפלחץתותחניםשריון
# A4
# מפקדיםות
# טג
# האקטובר
# תקבוצת
# התכניתנות
# וואטספ
# ויורה
# גדודיות
# לתוכניתן
# DIY
# 5גלחצ
# 95%
# מלאנים
# MODDED
# רוזנבלום
# תש2
# החי”ר
# קמד
# מנ
# לעתודה
# 4K
# תד
# אופקמודיעין
# miniere
# התותחניים
# כנף4
# מאוק
# בגובניקים
# הביסלח
# רמאכא
# דרקון
# בבאפ
# ירושליים
# ג׳ובניקתומך
# סינוסים
# שיריונרים
# לנהגסיכוי
# ההגנאכולם
# Vision
# בGoogle
# ויכול
# השירוט
# ההמבורגר
# הבאחים
# M5
# רפועיות
# אימביציל
# לחפשש
# ובאח
# נשקקרבי
# בקעבלט
# לירפא
# פאק
# צדמבר
# היקוש
# סטיגמות
# ‘תומך
# רגיזה
# אוג19
# 8200מה
# גדודמחלק
# ההטריל
# בנובמבר
# הרמלין
# קמנים
# רסרית
# ליסוע
# הבהלץ
# מפקדקציןבחייל
# מצריפין
# בחטמר
# שאבקש
# באיימיילים
# הבראור
# אגוזלמשל
# פורפיל
# קרפח
# ספציפים
# ידידההיא
# פרוייקטנט
# קדצים
# הג׳ובניקיאדה
# במקרפר
# לטומכל
# גיוסלאחר
# קיורטן
# הכנסו
# טנטון
# אימפטיגו
# היישאלה
# שריונרים
# סעמק
# למלשב
# מתייייי
# במקמצר
# וoverthinking
# המלשביות
# טאיטו
# קרבימדריך
# מקאם
# ‏ראש
# fmf
# הוקרערב
# 2סיגריותאלכוהול
# ל292020
# הוחםפיקוד
# לחר
# פיינטבול
# 8k
# בתקשוברוצה
# בחיפה
# מדחש
# ———התש——
# טכנולוגיץ
# בסייבר
# PDF
# הבצפר
# שגובניק
# לאוגוסט
# טישרט
# erp
# הרעינון
# היראור
# טרנינג
# כאישה
# מחסןתפקיד
# סירקיןמחנה
# בצבאתנאיםיציאות
# דבורנית
# רקטים
# בטלגרם
# להגנא
# טכנולוגי~
# היוש
# יעודית
# במקבילזה
# רנאר
# מקורונה
# Webint
# ימינית
# צלש
# הסילבסטר
# העדפותקרבי
# הגרויות
# בטכני
# המפחט
# נקעשבר
# קבנים
# בתותחנים
# סקסיסטית
# להתעייץ
# יחטיות
# הדריכהנופל
# מכתבמרשם
# צונגיות
# לGshock
# השיבא
# שנמצא
# reebok
# שבצר
# העלתי
# 4בחא
# וחיר
# בוואטסאפ
# פלחץתותחנים
# מדאג
# לכשרוץ
# אפילפסיה
# סדנאגאמא
# ראיוןסיווג
# לישאול
# ספרפנימייה
# ממכ
# מHyperhydrosis
# להתגייסתענו
# הוקמנדו
# הפסיכוטכני
# טורני
# בידיוק
# המנה1
# amazfit
# הגבי21
# אנח
# החרטט
# שיריונר
# זאתי
# דיכאונית
# אלקסאם
# הגהנום
# הבנדאם
# pros
# פריזמה
# העשות
# מוקטע
# לצבא
# ערעוק
# חוֹלוּת
# דחוףףףףףף
# אוטיזם
# באוגוסט
# בטרום
# הייחברה
# כפצת
# לפלחץ
# קרפ
# האלפייה
# הקטנאר
# לירושלים
# נגמחון
# הנחיותקורונה
# הדובדבןמגלןשלדג
# אוג20
# חלאס
# ברכבת
# להעלןת
# וצדכ
# בבחרפ
# הגובניקים
# דובדבןקומנדו
# לרסר
# יוםיומיים
# השריוןתותחנים
# שלצאת
# ש13
# הבאקום
# פליצות
# המחשבעזרה
# ההיתפנות
# אאיכוןmlrs
# גיבוק
# קרפפ
# לאוקטובר
# האפסדים
# קמבצ
# הליפטינג
# הכם
# מקצץמגלח
# יומים
# אוגז
# תצו
# וסמבצית
# תמסלול
# נגמשים
# ג׳וב
# נתממ
# תחולצה
# בצהל
# הטייסחובלים
# המכ
# ומיטב
# הגיטימי
# בCPR
# כיח
# בירכיות
# 50%
# איסופניק
# חימושניק
# שייטתקצב
# היהשמע
# 7תקשוב
# חחח
# דורזיסטן
# לקצונה
# תוכניתןלמי
# בh&o
# לגשת
# קקצ
# כלכליסט
# יאני
# לפנ
# פילונידל
# םטור
# משביזות
# מןביל
# מאחמ
# עתודהלא
# פלונטר
# היז
# קרביתחוץ
# ההיתגיס
# כןלא
# משמירה
# החיר
# הוקסרים
# הג׳וב
# והאם
# סטוצים
# כולםיתנו
# הפנות
# לחילוץ
# ראשלצ
# ועכובה
# בטשמאבטח
# 7שבס
# ארמ
# בצאוור
# היחל
# INEAR
# ‏איזה
# הטכניי
# הבלנמ
# טיסהיי
# שצצצ
# צבאילאומיאזרחי
# נפקדעריק
# רמד
# באזרחותעבודה
# דילמהיום
# יקינטון
# קורונות
# ויקיפדיה
# הרזרחות
# הפטורבן
# העזהעובדה
# הקסטינה
# לבלשרכז
# מגובניק
# ההופאה
# ללוחם
# למודיעיןתקשובתפקידים
# אןתה
# Columbia
# שפיעתודה
# זייון
# הידבגבס
# לחטיבהיחידה
# סימולציית
# לשאלותדרג
# רגליש
# תדברים
# וקדצ
# רפואיואני
# ויהלמ
# הA10
# שיחרור
# למצ
# חורון
# מג׳ובניק
# ריצת3000
# problems
# פסיכייטר
# דפרהייתי
# מזוןציוד
# רווחדפר
# שריוןהנדסהתותחנים
# לפראמדיק
# כמכ
# פראמדיקית
# רמתכל
# מימדית
# רודריגו
# הורת
# שתיכנסו
# הביסלמח
# 54דפר70
# וסיים
# חרטטו
# ייהלם
# דחוףףףףףךך
# נפשיהאם
# m4
# הימןדים
# מרתח
# דייחת
# נוב19
# תדרץ
# קפסקבן
# לבקום
# שירתת
# confessions
# בחימושלוגיסטיקהקשר
# it
# קבנ
# לעזעזל
# השבוע2
# רשמיעברנו
# המוצאהשם
# ו׳
# קבןאפשר
# הנחלאיזה
# העוזרים🙏🏻
# חמו
# שמבין
# גבולותתותחנים
# הכשרהסדיר
# מריך
# ברמ2
# שפהמי
# דתי20
# HP
# C1
# ג׳ובניקים
# פלחץ
# הSAS
# פרטיםפה
# תחחקיר
# בירושלים
# שמבקשים
# רןאה
# רשותקבע
# ממשטרה
# לעאזאל
# מצחיקיםהזוייםמעניינים
# מדאגנעת
# וובן
# המלשבים
# היוטיוב
# בקרקל
# סיירותגיבושים
# ההלומי
# העינייםבלי
# איפשהו
# המירמור
# היניהם
# עזרהלצאת
# טMLRS
# ביחיטיות
# שקפס
# 7מתמ
# VIP
# הסטיגמות
# כששואלים
# לצפטית
# ארנולד
# וייתור
# אחשלי
# בדחוףףףףףף
# ראשוןבדיקת
# ששעשו
# יכוך
# שסירבה
# חחודש
# החארת
# ואסאח
# שShall
# לחרפ
# הנות
# יאודי
# איבים
# למילואימניק
# הבנתע
# #2
# not
# לקדץ
# הינארי
# ווטסאפ
# בצהלרוצה
# ליברוח
# המעצרכלא
# YNET
# תפקידנהג
# אתאבו
# gshock
# גימליםםם
# ברובאיתגדודים
# בווטסאפ
# גבעצי
# אלקטורנית
# גולניגבעתי
# פרויקטנט
# ספאםמה
# הגדעונים
# לדרמן
# המודיעיןיחידת
# מרץ20
# הבהלצ
# ההתפשפש
# טאלנטים
# אחרתדחוף
# הזאתליחידות
# טיליםםם
# כוסאמאמק
# דיסטנסלדוגמא
# מרץ19
# מרהום
# נוצריהואני
# 1אני
# ספייר
# כשחותמים
# זהיה
# אליהםהם
# ליוטיוב
# ברמ
# הוואוצר
# ממיונים
# טרנס
# לגולני78
# suunto
# טיוליות
# חרטא
# הג׳וליס
# ינוארפרבואר
# לבנדוד
# האזחקה
# צבאימעצר
# הלוטםמפאת
# קפס
# פסיכאטר
# בגדנע
# כהנדסאי
# זנזיבר
# מראשןן
# אינסטגרם
# מונפצים
# השאוף
# סופשים
# מקןרס
# במחשבמגן
# מצלח
# המינסקוס
# חמןאו
# ט׳
# ההתסובב
# הקשההיום
# הטיחון
# וזוגיות😢
# הודדהתש
# ספלינט]
# קלביומיות
# מקצועוץ
# 55המלצות
# א׳ב׳
# תנתניה
# 1שאטל
# בוזזז
# סטילדבורומאוד
# האניגמה
# כוסאמק
# ראיונותגיבוש
# מסיייייבבבררררר
# תלסמיה
# זגורי
# סיגיט
# הגיוסהגיוס
# הרמבם
# בביח
# Wowimworld
# חגמ
# הפזםדופק
# קדס
# מסכורת
# המבחני
# הגדנע
# השריונרים
# ללוחמהלקרבי
# אמלחיסט
# אתרוגדברים
# הגינס
# 3גימלים
# הבגריות
# דחוףףף
# קרבי111
# הצעותטיפים
# המגבבבב
# מיימיהבקבוק
# gone
# סגןסרן
# קרביקשה
# מרץאפריל
# חבריםשאלה
# מקצעות
# וחא
# תאורתית
# בחפשנות
# אורטודנט
# יןצאים
# הפזמ
# הבאהבאיזה
# האווירמי
# תרחטים
# המיוןבבקשה
# היםשיבוץ
# הוואי
# חממניק
# גובתומךלוחם
# ביקורוםא
# יפלחץ
# 2קמ
# c1
# הבהלהbehala
# תפקידאי
# הארהבמוכרת
# במיקרה
# הייהוצאתי
# הטרצ
# 85מה
# ייגמרר
# חטל
# שקמיסט
# פראמדיקים
# לחימושניק
# צהלל
# ביחדזוגיות
# סולימאני
# קבא51
# הוע
# פרסונליזציה
# עוג
# AS
# #75181
# הבקשנ
# נבאלה
# צליאקים
# 17נוב
# קהספרופיל
# יג
# סופטשלפליז
# המדוייק
# וכאלה
# קלירנס
# שאבדנגנב
# נשקנחשב
# יו
# 4מצריפין
# האקדמיזטורים
# ללוחמהקרבי
# בשיזי
# שאטלים
# שאלותזכותי
# אוסים
# הרמלית
# הים‎
# אלקטרוניתאני
# נגביסטים
# מומנטמטאור
# שאלהעריק
# וומקום
# עזרה🙏🏻🙏🏻🙏🏻
# אזניות
# 72אסתמה
# בפלחץחיר
# ג׳
# אדרנלין
# תמבחן
# אק
# הדחש
# להטבים
# נחלאווים
# ג׳ובניק
# עטא
# הקקש
# עשיתםן
# שלא
# הירוקחיל
# הועיים
# while
# 97מודיעין
# קבנית
# קבא48
# שנהאיזה
# הסיכווים
# וחזרנווווו
# ביחטיות
# הייי
# בודעה
# מטלגרם
# וערקים
# שאלןת
# מכשירנית
# לכולםרציתי
# בגנא
# טיולית
# מילומיניק
# קשרגים
# atmos
# ביניהםבאמת
# המיטבית
# בהראדר
# שאלהמה
# לדצמבר
# אקדמיזציה
# בסטילים
# ליומיות
# בdarkweb
# 😅מקומות
# 2מטנקיסטים
# שינינית
# להלחליף
# לוקר
# לפסיכומטרי
# השאטל
# יהק
# fucking
# DSPS
# אבטשהגנש
# לציבור
# נסראלה
# הסלבס
# באופטימיות
# הכםלכול
# וכיפיים
# המשקית
# בחא
# למבינים
# דיפלופיה
# כטבמים
# מפסיכאטר
# יהל”ם
# קאדרשואל
# בביקוררופא
# אסטמת
# האווירנאוטיקה
# דאפר
# נחלאווי
# סבאסבתא
# מגדנע
# הmlrs
# קל־בינוני
# דיסקורד
# מינור
# פצעונים
# שאקבל
# סדנאת
# בקרייה
# יאלה
# קריון
# הולכתלעשות
# עייפים😣
# עוב
# אגדול
# כולשהו
# זקןשיער
# פספורט
# רחפני
# הצבאא
# ניימאר
# להתקמבן
# היסינג
# פתוחהמעקב
# הספאמר
# עזרההההה
# בירוקרטיתחוקית
# אוסקר
# שיכנס
# שמשרתיםשירתו
# ויחטיות
# חייבבב
# קהס41
# הפסיכומטריהרחבת
# ספליט
# סקופ
# בישראל
# הקטטנה
# S300
# exposed
# עזרההורדת
# מרסר
# בשיבטה
# מתגייסיםהתגייסתם
# הרפס
# הבנון
# בגבעתי
# הדפר
# שעלהקיר
# בm109
# במוצאש
# גאמאיסטים
# וחצי
# פלטפוס
# הוסחיל
# הפרופילאני
# התקשובתקשורת
# אחזקהטכני
# המרץאוגוסטנוב
# אינסומניה
# הטר
# במשפעה
# וOCD
# למודיעיןואין
# צנחניםדובדבן
# אעאעעא
# בשני
# איםה
# שעות24
# 😂😂
# הצבאפטור
# ברשתוחייב
# הבקוםאצל
# ביהלם
# לשצ
# לעוזרים🙏
# סופסוף🤔🤔🤔😁
# אפריל2020
# החחי
# המשרח
# Biggest
# מטכליסטים
# 64לוחמה
# בוקסר
# לינקיית
# הקבנית
# בנגמשים
# פרופורציונלים
# לק
# הצבא=50
# לחיר
# 99%
# בצנחניםכמה
# wrong
# טכנאית
# רלוונטים
# מכתוב
# הרווז
# חודשעכשיו
# סאונד
# גי
# למיקרו
# הצבאבבקשה
# ב׳
# הפטופ
# מלוחמה
# הפרפלגיה
# המנתץ
# מרדר
# שיוויוןשיגייסו
# צנחניםבעומק
# אופקגאונים
# שינים
# הגלצ
# לאיזו
# בועיים
# טיצינג
# הטחונית
# גודי
# הנירולוג
# שגדסרים
# מתתת
# שיפצור
# למביני
# היסטוריית
# f16
# קיטבג
# דחוופה
# וריקוצלה
# אינסטגרמים
# הצבאתפקיד
# 2020מתי
# std
# #92820
# גובניקי
# יוםיומי
# לגלצ
# מסובידור
# גופניקרב
# כשמתחפששים
# משגרואידים
# וחוגר
# הדצ
# איסה
# באדרנלין
# סרספ
# האווירשוחרות
# צכחכצע
# בפלחץ
# מוטיביציה
# מ־8200
# הצלטמתי
# קומנדומגלן
# גילדרגה
# שעדייח
# בגוב
# team
# הברוח
# 4ג
# סרבות
# DW9052
# בFXP
# לטיס
# פרויקטנטים
# בצלמון
# למדאג
# להתכוננן
# vs
# הלנמ
# קאלק
# דחוףףףף
# הקורונה
# אממ
# דפר90
# cons
# בבאן
# שחקיםאמנון
# פאקטים
# 64איך
# הבהד20
# WTF
# האוויר>טכנאי
# מולטיפוקל
# פיקטין
# רגילטיפים
# mavic
# הקבעמילואים
# הבאח
# תשביזות
# אסטמה
# וחמן
# רואקוטן
# קרביאחר
# בפרופיל
# שצ
# וסופטשל
# אנמיה
# המשרדתית
# אלללה
# משפקיים
# עושיםעשיתם
# פעילספורטאי
# @the
# aztec
# כשעולים
# בהתחלת
# #82893
# הסמבצית
# יכןל
# הללית
# מישו
# לגדסר
# לגיוסאחרי
# יב
# לעזרה❤️
# עלאת
# ישלי
# ביצוגיים
# אתראפליקציית
# הבקום
# וודעה
# ברכבתאוטובוס
# מקבןכמה
# הדצמבראני
# הרסןסאל
# השחקיםחבצלות
# פלסטפוס
# דיגטלי
# לממ
# תבהלו
# גולד92
# תומכל
# נאבללה
# הסיכוייםשלי
# אוס
# מטמתיקה
# NSFW
# חחחח
# מתקניםאיך
# מחופששים
# באנגלית
# היתם
# אלבגדדי
# משפיעב
# ושיחרור
# עושהמשלים
# פתוחבסיס
# מעונין
# תיאורתית
# הדרוםקהס
# ברגדה
# IT
# וכו
# פרפכנסו
# גאמאאניגמה
# ARMA
# לשאול…
# ואוגוסט
# לSnow
# חימושיג
# בגאמא
# בגדוד
# צוללותאשמח
# א׳
# ביסלא
# הפרוטקציונרים
# קורסהכשרה
# שחמ
# עדפות
# נסראללה
# פפר
# הוטרחרוב
# ocd
# ההיטס
# הדינורריבועים
# בימחים
# לעוזרים
# פקמצית
# הפרבואר
# מידעמשק
# המשלבאיזה
# פציעהעכשיו
# השחיפים
# סינוס
# אזמכתא
# TRex
# הוואטסאפ
# היטחוני
# מיניזםםםםםםםםםםםם
# משטרהנושא
# הb52
# לדעאש
# ההנדסאים
# הצבאכמה
# מלשבזה
# הרומוזום
# גוגינס
# שבס
# כפירלא
# שאיזור
# בענן
# בחודש
# המילואמניק
# וואטסאפ
# הצהל13
# האלפיה
# Analyst
# הטש
# למי
# מתייייייי
# יא
# מיומיות
# מיחידת
# המפקדיםקצינים
# חי”ר
# היטחוניקבט
# המקרפר
# למפקד
# הרלצ
# ישנ
# שאומרים
# לרמ2
# אf15
# באג
# לט
# החמליסט
# הקבאהדפר
# רפואינפשי
# הPrEP
# ראיוןגיבוש
# 5לאוגוסט
# ביהלום
# תפקידמם
# למזי
# אתזה
# וויד
# תפקדיפ
# עייייפיים
# אפסנאית
# הפלסר
# תאשכול
# היוהם
# ההגיסטים
# ראקוטן
# ופאקינג
# אבצס
# #21
# מדוגם
# להרכיח
# בבקום
# מינימלים
# התואר”
# מיונז
# מptsd
# קלש
# בגבול
# הקבן
# טרמפ
# OCD
# לשאטל
# לפלסר
# הקהס
# וקהס
# מצטייןפעיל
# למרץ20
# עירעור
# שמתלונן
# כנפץ
# אוסגוד
# לבאח
# המיטבביחד
# חייליםאסירים
# השזפון
# קודס
# הסיגיט
# ל0705
# מגלןפלחהןפלסר
# חוףמרכז
# טכנולוגיגאמא
# IWI
# צריפין
# מדרסיםריפוד
# הצבאיםהאם
# בסופטשל
# יוטיוב
# Add
# צנחניםראיון
# ב40
# להתנדביוכלו
# לתהקלח
# הצוםאפשר
# בטרצ
# מצוב
# כנסווו
# בחורף
# הגנ
# טובים❤
# בשיחרור
# מדאגיםימח
# שמביןרמ
# ופליז
# ההיתגייס
# בחטל
# ווצאפ
# סופשטל
# פסכיאטר
# בקבא
# השלוקר
# יכרילו
# המתאימיםצריך
# היתייצבות
# חרירית
# תאונותדריסות
# מגרבבים
# הגדנעים
# בפלסר
# מיוו97
# בכספ
# החטמרים
# תבץ
# הצריפין
# הפנמ
# קורל
# אחוזמעודכן
# שיובץ
# נשיםלוחמות
# הנתממ
# הנידפקו
# תסרטון
# נורמים
# במתגייסים
# בצאלים
# הטרמפיאדות
# בועייםשלוש
# thc
# חיבלים
# pro
# סופטשלים
# הלוגיסטיקהתורנות
# world
# העוזרים🙏🏻🙏🏻
# ברהן
# ריספרדל
# כאלקטרונאית
# העוזריםנמצא
# הפלפון
# אמלחייה
# ביסלמח
# אודומות
# המדאג
# קליקים
# לינוקס
# בצנחנים
# אישתתף
# 83דחוף
# בקהללא
# הג׳ובניק
# הבחמס
# לתשאז
# סרטוןסדרה
# ולייט
# בגוגל
# מישאו
# תיהיו
# סקרחיילים
# טט
# תוהד
# מראשלצ
# האווירחיל
# הכריסמס
# פקלשית
# לג׳ובלמישהו
# גלחצ
# גדנעות
# מעבריםסיירת
# נחלשמע
# DAHOF
# טופס55
# לאיזה
# הגדים
# אישיותיים
# תירונות
# המטכני
# מזאר
# 100%
# ובסיס
# משקית
# וקבנית
# הוגיסטיקה
# מוהנדס
# הנהדסה
# בפלמחים
# אלקרונית
# יוהלם
# פיתחים
# מקצועילמדתי
# היטחון
# פץלהתגלח
# דיגום
# קסטינה
# טראנסים
# אלבגדאדי
# הטכנישוחר
# באפליקצייה
# גימליםבתים
# למלחמה
# הראיון－
# תמפקד
# המאסטר
# דמשיהו
# עזרהה
# מקרפ
# עוברעבר
# תחבצ
# הקדץ
# SMS
# MRI
# תוכניתן😅
# גלדיולה
# גןקריית
# מתגייסלקחת
# אדמח
# מדריךת
# הנובמברדצמבר
# שמעניין
# איקיו
# ורסטילית
# באונברסיטת
# המבס
# מיוניםקודם
# שיבוץתאריך
# חכמ
# ייצוגית
# פההציעו
# רביעיאני
# קורסגיוס
# להוצי
# ענתות
# גיוסאישור
# center
# מהטכני
# ואוצר
# המודעין
# הגיוניצו
# wakawaka1
# טרול
# הוחמה
# לעשותאובד
# ג׳וליס
# תוצאותוויתור
# וואוצר
# במנילה
# אורטוסקופיה
# בהגנא
# חחחחח
# פלחצ
# עדשוצ
# פנימייות
# בלעלות
# אסוציאציות
# היהדומהואיך
# פקלים
# לבהד
# קהס60
# בנובי
# לוגיטק
# החוחמים
# הביינישים
# המדריח
# כירורג
# 5שמור
# ‏כ100
# ימנים
# סיסטםמנהל
# בחי”ר
# היסמ
# believe
# ומגלן
# דצבמר
# 2בדצמבר
# כתפקיד
# טרנסגנדר
# האממ
# פדן
# הm4
# כושרקבן
# שם…
# הקנות
# החופלים
# מישה
# שרוןרוצה
# dc
# מדאגכבר
# וסבתא
# וסורבתי
# שהד
# להנחיות
# II
# #27391
# במודיעין
# בפסיכוטכני
# הגדסרים
# מאוג20
# טריג
# למקומה
# ראשוןןן
# סינוסיטיס
# עוסים
# כסףכלומר
# נתממניקיםאנשים
# מחרותיים
# מומלץמפוחלץ
# סיבולתכח
# לתפקידים
# YOH
# הסטילים
# הערבאני
# טנקיסט
# תפלנלית
# שחיף
# מקרבימגב
# בביסלא
# זקל
# שתיהיה
# ספלינטס
# ליוליאוגוסט
# טרצ
# גדודשואל
# בגנין
# שישישבת
# מיוטיוב
# מאוגוסט
# השרינורים
# הפלחץ
# הכלצ
# לסיגיט
# בראשוןרוצה
# מיוןשיבוץ
# הקרונה
# ראיוןאשכול
# dreamer
# חיספין
# ודפר
# כלליתמה
# הצבאחייב
# מרצונה
# 7VS
# הסאונד
# דחוףבגיוס
# צליאקי
# לטכני
# הקבא
# ופרופיל
# עכישו
# Remember
# גנץ
# תשובהטופס
# גולניאימון
# חמשושים
# מתקניםנהג
# הקרביקציניםנגדיםמפקדיםחפשים
# למתשמש
# Iגם
# ass
# שתקראו
# חמשיר
# לקבא
# חלפצ
# לאנדרנלין
# תגובניקים
# מאכא
# מיוןורוצה
# בינואר
# זיגייר
# לטובה
# הנסדאי
# דחופהה
# חוגרון
# sms
# אוויוניקה
# צבאפרופיל
# כויוצאים
# הראשןם
# היילא
# m16ai
# היפוטוניה
# סתיגמות
# ‏יש
# הarקי
# הTikTok
# הגיוסצריך
# וואי
# זימוניםמיונים
# ambit
# תיואם
# בסופשים
# חבריו‎
# בביקורופא
# האגוזמגלן
# מגבימס
# שאחרי
# התים
# לישראל
# ימלמ
# דילדו
# הדיסקורד
# נקנש
# דאבורסאטיל
# לצהלאבל
# טלגרם
# זמןן
# הקפסולות
# בסימולטור
# צבאילאומי
# המחשבסייבר
# וקשייםלא
# טגח
# בפירוט
# מטכלשייטת
# תיאוריטית
# לקשרג
# סיסטם
# כאלה
# בחופש
# יחיזרו
# יילך
# סטרפטוקוקוס
# חננות
# האישיותיים
# סמבץ
# דחוץ
# חבריא
# המדפסים
# אופקאופקים
# וצהל
# פליז
# השומרמחווה
# מצבא
# הסיכןי
# ימל
# imiss
# חייליקציני
# אסמבצ
# ווש
# קשרגית
# oti
# היתקשרה
# data
# 30k
# 2פיקודי
# שייטתמטכל
# FootLocker
# למגבעדיפות
# הוסעמק
# אוטמטית
# לביקוררופא
# ותכף
# אז…
# מכית
# אולרסכין
# הסטיל
# דובדבןמקום
# הגדסר
# המשקיות
# בוואצאפ
# סייברחבצלותורדיםאננסי
# הנגמשים
# מימז
# מביפנים
# מקהס
# לוםאני
# העדכניים
# באן
# הקפס
# משהדפפ
# בגדודבסיס
# עוקץלפי
# 2דחוףף
# אלרגני
# הטנאחימוש
# המאהתחנות
# הג’ובניקים
# היחידהה
# ל90
# מבש
# בתכלס
# ליומסניקים
# איךאני
# סדכ
# לכירורג
# אחשומוטה
# רומיידה
# המקצעות
# במאג
# יאא22
# קליק
# רפואימלשב
# ילתם
# רפלוקס
# אסימטריה
# possible
# מבאח
# cant
# לעער
# ההלצ
# השבל
# קבןחייב
# שהוועדה
# מלוחמים
# נגיגה
# יופ
# הגדאדי
# ימחים
# מטכני
# היירציתי
# טכנולוגית>טכנאי
# D_
# צליאק
# ברזלקלע
# ה669שלדג
# FUCK
# יסמג
# החטמר
# the
# נשקשואל
# תז
# הריקושט
# אפלפסיה
# קורונה
# nigga
# היגיינה
# עיינים
# גדנא
# להיתגייס
# שגוב
# אבתלפיות
# ג’וב
# המגלןמישהו
# איהק
# מעפן
# צריל
# ספלינט
# Maps
# טקטיאשמח
# אקסטרניים
# משתחרים
# six
# החובליםצוללות
# תיכנסוווו
# F15i
# גובניקים
# וקבא
# מג׳וב
# תחוגר
# סאלים
# expose
# דח׳ש
# rise
# קשפל
# הטירונותהגיוס
# המלשב
# גולדין
# הוחמים
# משתמטיםמתגייסים
# שממ
# מגלןשייטת
# היחטיות
# ביוטיוב
# דודבדבן
# סייבר8200
# האכא
# נעםניב
# עוזחטיבה
# חמן🇮🇱
# האלחוטנית
# האבטחב
# בבהלצ
# #מחזירים_את_רחמים
# הטלגרם
# קבלתאי
# פאצים
# צ׳יפים
# לחיילים
# בירושליים
# הדצ19
# אספלט
# כיביכול
# מייםמורןדיה
# הסוףפב
# הפינלנדי
# נוב16
# תוכניתןסיווג
# ביחידה
# אקוורויום
# בלבנון
# wtf
# דקסמול
# #3
# יאא
# מרומ
# ישהייתה
# פסיכאטריות
# 2ביתים
# תתפקיד
# אזשהי
# ממילואים
# ראשוןאשמח
# שעושיםעשו
# תשיבוצים
# בגדסר
# מוחדות
# הליכון
# 7אפילפסיה
# משפחהצד
# הפירניק
# overrated
# קרביאושר
# שדורש
# היהלם
# מגלן🦅
# לSMS
# ביאא
# קלסטרופוביה
# מאוויחים
# הממשלהמישהו
# הקרבי55
# שתיכנס
# תגב
# למכים
# נצחנים
# תכנאי
# רוסטסקי
# נפגשיםיוצאים
# הוחמותמחייב
# טריילר
# army
# הפיסכוטכני
# ו471כ
# שאחות
# מתשאליפ
# שאלך
# לגובניקים
# בחהן
# שמישנוא
# חמליסט
# תקפידים
# באפ
# בגולן
# הDNA
# קאמפינג
# ישפיעה
# שיערהאם
# למרץ21
# חדכ
# ממרמ
# ראינות
# חובליםצוללות
# צאנס
# גוייז
# תיקוןהאם
# הקונפשיינס
# סורבתי
# גסדר
# ותש
# התקבלתיי
# לגולני
# באיוש
# גאמה
# 18ב
# הקצונהפיקוד
# מאחזק
# יבניק
# בועשבוע
# סוציופתים
# #1
# הוטם
# והבקום
# הדיגום
# טכנולוגים
# כחיר
# טובותיחס
# מתלהבים0
# הדיסטנס
# מאגיסט
# לstupid
# webint
# ממשקית
# יוםמתכנן
# נראלי
# האפלפסיה
# התנדבותית
# רייסרים
# דגנרטיות
# what
# בלייזר
# בחרפ
# מכירוג
# אפטש
# שמעשן
# הפסיכיטאר
# יעול
# לקרביכללי
# בבהדים
# אחרכן
# לנובמבר
# סטיליםדבורים
# וגטקס
# ההדיע
# HAHO
# עדפון
# פטורזה
# חפשני
# 9מתי
# מטאורןלוגית
# נחלחייב
# סטיגמה
# נק
# התיקשוב
# יהלמ
# הטכנולגיה
# הsms
# חראות
# במצ
# הקדמהדחייה
# מ2009
# מקצי7
# סקאביאס
# ממגשימים
# סימולטור
# טראמפ
# אסמכתה
# איךךך
# סטילן
# רראיונות
# גיבושון
# צבאי15
# האבטש
# חוששבים
# רעלל
# להוזיז
# ברנד
# ידהנדסאי
# חטיבהבערך
# לקהס
# מניסיוןשמועות
# היפואלרגני
# תפקידיםמפעיל
# יוליאוגוסט
# שעשה
# מינוס
# מגעמדאג
# הדרכ
# מספן
# נחלסיירת
# הגיוסבגלל
# גידעונים
# פרייאר
# פציעהמאותר
# ממממממממממ
# גיאופוליטיים
# דיכאום
# ייחודיאפשר
# לוט”ר
# האסוציאציות
# Gshock
# צנחניםמגלן
# הסגעייה
# האורטופד
# בועים
# חבר׳ה
# BMI
# פייגלין
# הMLRS
# אקשן
# תכומתה
# בM16
# בשצ
# שאלההה
# לשריונרים
# האולטמטיביים
# 3פעמים
# בבקשהאני
# נובמברדצמבר
# פוליפ
# משמועותיים
# עריקותנפקדות
# בגיהאד
# חריגהעלאת
# ילמ
# נהנתםנהנים
# מגלןדובדבן
# קרקל
# אתלפיות
# בשבס
# שגדסר
# ותלפיות
# וגימלאים
# ריקושט
# כלוחם
# איתןאיתור
# בוע
# ליהלם
# החירגבעתי
# מגוב
# בביסלמח
# המאהתאריך
# בתגלית
# בזמן
# תפרופיל
# באינסטגרם
# הקומדנו
# להיתגלח
# ההיופ
# שחיר
# בגדאדי
# ההגנא
# הקנאביס
# המבורגר
# כבראם
# קלנדרית
# האמבוש
# קרינג
# לאטה
# לתכנאי
# לספרים
# פרוייקטנטים
# משבוע
# אסימולטור
# לייטרובאי0305
# לסנא
# צB
# בכפיר
# הצהלנטחנים
# אונליין
# 43תש
# כלללל
# 5יח
# המתנהנהג
# לעשותהורים
# הצאליםבאפ
# חלפס
# סמח
# סולייה
# זכאון
# מילואימניק
# היינישים
# מרכזצפון
# האווירעוד
# החמשושים
# אגוז<סיירת
# מאשקלון
# איזנקוט
# הרסר
# מלר
# פקידג׳ובניק
# העשותפציעה
# הראור
# הזוייה
# והמורה
# וגדסרים
# 20פרופיל
# העורףתומך
# הוחם
# אטאיסטים
# טש
# 20😢😫😩
# לרמ
# ותשפטו
# קנר
# f350
# התותחניםמרוצה
# מששחות
# שיוצא
# ופלטפוס
# וקורונה
# חרידי
# לחופל
# מצה׳ל
# מתפקחד
# אוקסיד
# הקראש
# תפקחד
# בסמח
# עפ
# הגנא
# באינרנט
# דיוןלאן
# הקורל
# מתחפשששש
# mlrs
# היקרבי
# דפר50
# תשמירה
# ידפרויקטנטים
# iq
# ייעדוי
# הימודית
# ההגיון
# מדאטראומה
# הפקדון
# המקיסימום
# שריוןתותחנים
# הקורונהלא
# סמבצית
# פסיכוטכני
# בינאור
# התוכניתנים
# טובזה
# כלבניםכלבניות
# לכולםאתם
# ספירומטריה
# #27392
# ממטאג
# לאטר
# Tesa
# עפרוני
# יוליאוג
# שאני
# שביקור
# 03ואחרי
# אפשרותלראות
# הגאמאסייבר
# השימושון
# באיזה
# מישהן
# משירוט
# חרובצוות
# הקבןחרפ
# סופש
# הסרספמשהד
# מדאגים
# חיזבאאלה
# הבארגילה
# לאילת
# הייטק
# הוכבים
# בצחל
# אלוףרמטכל
# M4M16
# תוכניתנית
# טאלנט
# נגדבלי
# טייץ
# ממיטב
# סהכ
# בקבע
# קדץ
# שיבוץהשיבוצים
# הקלאץ׳
# הצבאועדת
# הסמחט
# האנדרואיד
# מהסדיר
# טיפ
# הסנטגין
# 0000אחגוג
# אישורוהורשע
# להיותתותחנים
# כזהשמע
# רפליקה
# מחבר׳ה
# המצוב
# ב263
# מרמ
# הבקשהמי
# בקדץ
# השבס
# מתצפי
# מתישהו
# _פטור
# be
# השלישותמחנה
# DEUTAN
# [1710]
# נחלוואי
# מיוניים
# מפלחץ
# אנטבה
# למיבינים
# לחבצלות
# שקרפפ
# לקבנית
# ההתשמש
# פקטים
# לעין
# גיהאד
# תכף
# לשיבוץיחידה
# מדצמבר
# פופקורן
# היפוטטידוח
# גובניק
# לייט
# גיוסשיבוץ
# bmi
# מתומך
# עתודב
# הקתבים
# אתכלס
# בfxp
# הוקח
# דחווווף
# המוביט
# בנחל
# עדכנימרץ
# ראשוןשבת
# נה
# הלוחמהאיך
# למדתים
# מודאל
# ממדאג
# גמילים
# חוליםמיון
# הSMS
# ברסרית
# הנדסאים
# Aztec
# לעשותו
# באייפד
# אושקוש
# הוחחחחחחחחח
# הסמח
# התקשובתומך
# תעודהמסמך
# יציא
# הדיסקית
# פאקינג
# החפק
# הידודצינוק
# שאלהיש
# היוםםם
# סיירותיש
# מעוקץ
# הקורונהה
# בימס
# דילמהמכינה
# להיתכונן
# קמני
# המנטליים
# המנתץmlrs
# שירתמשרת
# טיסשאלה
# וויסט
# בפסיכומטרי
# הטסט
# במודעין
# בנהגים
# הDEA
# ביומיות
# swat
# קמ
# המפ
# המיוןאני
# חיילח
# פיברומיאלגיה
# קבןקפס
# האסמבלי
# חחחחחחחח
# להיזדכות
# הממיני
# חייליל
# בחמן
# שיננית
# קשח
# הכתףלא
# באילת
# מביךגיבוש
# בתקשובמפעיל
# האולטרה
# אחמ
# מודיעיןעזרה
# תתאריך
# USB
# יומסיום
# מאבח
# הלטבקע
# וצונגיות
# הייקריים
# במאיר
# הm16
# Ocd
# הסימולטור
# שחפרתי
# האיכוןאיך
# תלפיות
# תקשורתמנהל
# eotech
# למדינות
# שיעראיך
# סטייל
# הסיסישיבת
# לעתיד
# מחרנשאר
# SHOCK
# בולשיט
# המלצההההה
# בתחבצ
# שוויתרתי
# בגימלים
# היייי
# בחג
# גאמאטכניהטקלות
# הקבט
# שהתמכר
# תש5
# במזי
# ראשון99
# 24רמ
# seals
# סרוב
# הfxp
# שאטל
# רפואים
# הבקשה~
# בחימוש
# ההיתי
# פפ
# שאפשר
# הקחת
# בתתוחניך
# ספירמודיעין
# ל30
# בנט
# בקואימון
# מאליאקספרסס
# לבהדים
# הגיל26
# מגנס
# התרגד
# מפעילטכנאי
# ערקון
# בקמכ
# האווויר
# חירהנדסה
# שגיובש
# אפצים
# בנתניה
# המניסקוס
# הביסלא
# כבנאדם
# הש3
# ניקוו
# הטינדר
# 3vs
# מלשבים
# הפניהבדיקות
# הגעטיפול
# עקשת
# חזיבאללה
# מתמ

# %%
f = open('problematic_words.txt',"w")
for word in problem_words:
    f.write(f'{word}\n')
f.close()
